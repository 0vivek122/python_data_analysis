# %%
import pandas as p

# %%
import mysql.connector as con
mydb = con.connect(host = 'localhost',user = 'root',database = 'task',password = 'P05r 0t 6u4 %9jye') #making the connection with mysql
c= mydb.cursor()

# %%
da=p.read_excel('Attribute DataSet.xlsx') #reading the excel file  here 
da
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
da.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
da.isnull().sum() #checking the null values
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# waiseline          87
# Material          128
# FabricType        266
# Decoration        236
# Pattern Type      109
# Recommendation      0
# dtype: int64

# %%
da=da.fillna("<na>") #filling all null values
da
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           <na>     chiffon     ruffles
# ...

# %%
da.to_csv('atrri.csv',index = False) #converting the da dataframe into csv file

# %%
da1 = p.read_csv('atrri.csv')
da1 #reading the csvfile
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           <na>     chiffon     ruffles
# ...

# %%
l=da.dtypes.index # these are the column name of table

# %%
da.columns = [i.replace(' ','_') for i in l] #removing the white space in column name
da.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern_Type', 'Recommendation'],
#       dtype='object')

# %%
replacement= {'int64': 'int(50)',
             'object': 'varchar(50)',
             'float64': 'float(50)'}

# %%
tuple(zip(da.columns,da.dtypes.replace(replacement)))
# Out:
# (('Dress_ID', 'int(50)'),
#  ('Style', 'varchar(50)'),
#  ('Price', 'varchar(50)'),
#  ('Rating', 'float(50)'),
#  ('Size', 'varchar(50)'),
#  ('Season', 'varchar(50)'),
#  ('NeckLine', 'varchar(50)'),
#  ('SleeveLength', 'varchar(50)'),
#  ('waiseline', 'varchar(50)'),
#  ('Material', 'varchar(50)'),
#  ('FabricType', 'varchar(50)'),
#  ('Decoration', 'varchar(50)'),
#  ('Pattern_Type', 'varchar(50)'),
#  ('Recommendation', 'int(50)'))

# %%
s =''
for i,j in zip(da.columns,da.dtypes.replace(replacement)):
    s = s+i+' '+j+','
    
s= s[0:-1]
s
# Out:
# 'Dress_ID int(50),Style varchar(50),Price varchar(50),Rating float(50),Size varchar(50),Season varchar(50),NeckLine varchar(50),SleeveLength varchar(50),waiseline varchar(50),Material varchar(50),FabricType varchar(50),Decoration varchar(50),Pattern_Type varchar(50),Recommendation int(50)'

# %%
c.execute('create table Attribute ('+ s +')') #creating the table

# %%
#now inserting thte values in table Attribute
for i,row in  da1.iterrows():
    c.execute("insert into Attribute value(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",tuple(row))
    mydb.commit()
print('all inserted')
# Out:
# all inserted

# %%
c.execute("select * from attribute") #executing the sql query
c.fetchall()
# Out:
# [(1212192089,
#   'Casual',
#   'Low',
#   0.0,
#   'L',
#   'Summer',
#   'o-neck',
#   'Petal',
#   'natural',
#   'microfiber',
#   '<na>',
#   'ruffles',
#   'animal',
#   0),
#  (1190380701,
#   'vintage',
#   'High',
#   0.0,
#   'L',
#   'Automn',
#   'o-neck',
#   'full',
#   'natural',
#   'polyster',
#   '<na>',
#   '<na>',
#   'print',
#   0),
#  (966005983,
#   'Brief',
#   'Average',
#   4.6,
#   'L',
#   'Spring',
#   'o-neck',
#   'full',
#   'natural',
#   'silk',
#   'chiffon',
#   'embroidary',
#   'print',
#   1),
#  (876339541,
#   'cute',
#   'Low',
#   4.5,
#   'M',
#   'Summer',
#   'o-neck',
#   'butterfly',
#   'natural',
#   'chiffonfabric',
#   'chiffon',
#   'bow',
#   'dot',
#   0),
#  (1068332458,
#   'bohemian',
#   'Low',
#   0.0,
#   'M',
#   'Summer',
#   'v-neck',
#   'sleevless',
#   'empire',
#   '<na>',
#   '<na>',
#   '<na>',
#   'print',
#   0),
#  (1220707172,
#   'Casual',
#   'Average',
#   0.0,
#   'XL',
#   'Summer',
#   'o-neck',
# ...

# %%
p.read_sql_query("select * from attribute",con =mydb) #execution in better way
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           <na>     chiffon     ruffles
# ...

# %%
#Try to find out how mnay dress is having recommendation 0
p.read_sql_query("select count(*) from attribute where Recommendation =0",con =mydb)
# Out:
#    count(*)
# 0       290

# %%
#converting the atrribute into json 
da.to_json('Attribute.json')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           <na>     chiffon     ruffles
# ...

# %%
import pymongo  #importing mongo 
client = pymongo.MongoClient("mongodb+srv://vivek1:5X2oq4TGif9drMbm@cluster1.ivrgot3.mongodb.net/?retryWrites=true&w=majority")
db = client.test
"""making connection with mongodb"""
# Out:
# 'making connection with mongodb'

# %%
#import it into mongodb the json file
import json
f= open('Attribute.json','r')
d=json.load(f) #we reading the json file
db = client['task']
coll = db['atrri']
coll.insert_one(d) #here we inserted

# %%
#Reading te new file that is dress 
d = p.read_excel("Dress Sales.xlsx")

# %%
d.isnull().sum() #checking the null vaules
d=d.fillna(0) # filling them
d
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
d.to_csv('dress.csv',index = False) #converting to csv

# %%
c= ['`'+str(x).split(' ')[0]+'`' for x in d.columns]
c
# Out:
# ['`Dress_ID`',
#  '`29/8/2013`',
#  '`31/8/2013`',
#  '`2013-02-09`',
#  '`2013-04-09`',
#  '`2013-06-09`',
#  '`2013-08-09`',
#  '`2013-10-09`',
#  '`2013-12-09`',
#  '`14/9/2013`',
#  '`16/9/2013`',
#  '`18/9/2013`',
#  '`20/9/2013`',
#  '`22/9/2013`',
#  '`24/9/2013`',
#  '`26/9/2013`',
#  '`28/9/2013`',
#  '`30/9/2013`',
#  '`2013-02-10`',
#  '`2013-04-10`',
#  '`2013-06-10`',
#  '`2010-08-10`',
#  '`2013-10-10`',
#  '`2013-12-10`']

# %%
replacement = {
    'int64':'int',
    'object':'int',
    'float64':'int'
}

# %%
s= ''
for  i,y in zip(c,d.dtypes.replace(replacement)):
    s= s+i+' '+y+','
s=s[:-1]
s
# Out:
# '`Dress_ID` int,`29/8/2013` int,`31/8/2013` int,`2013-02-09` int,`2013-04-09` int,`2013-06-09` int,`2013-08-09` int,`2013-10-09` int,`2013-12-09` int,`14/9/2013` int,`16/9/2013` int,`18/9/2013` int,`20/9/2013` int,`22/9/2013` int,`24/9/2013` int,`26/9/2013` int,`28/9/2013` int,`30/9/2013` int,`2013-02-10` int,`2013-04-10` int,`2013-06-10` int,`2010-08-10` int,`2013-10-10` int,`2013-12-10` int'

# %%
c.execute("create table dress ("+s+")") #created the table

# %%
d1=p.read_csv('dress.csv') #reading csv file
d1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
for i,row in d1.iterrows():
    sql = "insert into dress value(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    c.execute(sql,tuple(row))
    mydb.commit()
print('inserted all')
# Out:
# inserted all

# %%
d3=p.read_sql_query("select * from dress",con = mydb)
d3
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09  2013-04-09  2013-06-09  \
# 0    1006032852       2114       2274        2491        2660        2727
# 1    1212192089        151        275         570         750         813
# 2    1190380701          6          7           7           7           8
# 3     966005983       1005       1128        1326        1455        1507
# 4     876339541        996       1175        1304        1396        1432
# ..          ...        ...        ...         ...         ...         ...
# 495   713391965          0          0           0         560         554
# 496   722565148          0          0           0         875         866
# 497   532874347          0          0           0         734         728
# 498   655464934          0          0           0         254         259
# 499   919930954          0          0           0         538         545
#
#      2013-08-09  2013-10-09  2013-12-09  14/9/2013  ...  24/9/2013  26/9/2013  \
# ...

# %%
#Write a sql query to find out how many unique dress that we have based on dress id
sql= "select count(distinct(Dress_ID)) from dress"
p.read_sql_query(sql,con = mydb)
# Out:
#    count(distinct(Dress_ID))
# 0                        475

# %%
sql= "select count(distinct(Dress_ID)) from attribute"
p.read_sql_query(sql,con = mydb)
# Out:
#    count(distinct(Dress_ID))
# 0                        475

# %%
#Try to find out total dress sell for individual dress id 
sql = """select 
Dress_ID,
sum(`29/8/2013` +               
`31/8/2013` +               
`2013-02-09`+     
`2013-04-09`+      
`2013-06-09`+ 
`2013-08-09`+     
`2013-10-09`+    
`2013-12-09`+     
`14/9/2013`+               
`16/9/2013`+               
`18/9/2013`+               
`20/9/2013`+
`22/9/2013`+               
`24/9/2013`+               
`26/9/2013`+             
`28/9/2013`+                
`30/9/2013`+             
`2013-02-10`+   
`2013-04-10`+   
`2013-06-10`+      
`2010-08-10`+    
`2013-10-10`+  
`2013-12-10`) as total from dress
group by Dress_ID"""
p.read_sql_query(sql,con = mydb)
# Out:
#        Dress_ID    total
# 0    1006032852  75979.0
# 1    1212192089  52256.0
# 2    1190380701    223.0
# 3     966005983  39691.0
# 4     876339541  44077.0
# ..          ...      ...
# 470   990559192   1427.0
# 471   713391965   8915.0
# 472   532874347  12606.0
# 473   655464934   5167.0
# 474   919930954  12312.0
#
# [475 rows x 2 columns]

# %%
#Try to find out a third highest most selling dress id
sql ="""with t as(
select 
Dress_ID,
sum(`29/8/2013` +               
`31/8/2013` +               
`2013-02-09`+     
`2013-04-09`+      
`2013-06-09`+ 
`2013-08-09`+     
`2013-10-09`+    
`2013-12-09`+     
`14/9/2013`+               
`16/9/2013`+               
`18/9/2013`+               
`20/9/2013`+
`22/9/2013`+               
`24/9/2013`+               
`26/9/2013`+             
`28/9/2013`+                
`30/9/2013`+             
`2013-02-10`+   
`2013-04-10`+   
`2013-06-10`+      
`2010-08-10`+    
`2013-10-10`+  
`2013-12-10`) as total from dress
group by Dress_ID),
t1 as
(select *,dense_rank() over(order by  total desc) as rnk from t)
select * from t1
where rnk=3
"""
p.read_sql_query(sql,con=mydb)
# Out:
#      Dress_ID    total  rnk
# 0  1006032852  75979.0    3

# %%
mydb.close()

# %%
#in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID

# %%
sql= """select * from attribute as a left join dress as d on a.Dress_ID = d.Dress_ID"""
p.read_sql_query(sql,con = mydb)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 545   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 546   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 547   532874347   Casual  Average     4.7     M  Summer     v-neck
# 548   655464934   Casual  Average     4.6     L  winter  boat-neck
# 549   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  ... 24/9/2013 26/9/2013 28/9/2013  \
# 0      sleevless    empire           <na>  ...      3554      3624      3706
# ...

# %%
mydb.close()
