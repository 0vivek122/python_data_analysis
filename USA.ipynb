# %%
import pandas as p

# %%
import mysql.connector as con

# %%
mydb= con.connect(host = "localhost",user ='root',database ='task',password ='P05r 0t 6u4 %9jye')

# %%
c= mydb.cursor()

# %%
do = p.read_excel('Superstore_USA.xlsx') #reading the order

# %%
do
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
dr = p.read_excel("Superstore_USA.xlsx",sheet_name = "Returns") #reding the returns
dr
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
du = p.read_excel("Superstore_USA.xlsx",sheet_name = "Users") #reding the users
du
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
do.isnull().sum() #checking the null
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
do['Product Base Margin'].fillna(0,inplace= True) #filing the null values

# %%
r= {'int64':'int','object':'varchar(100)','float64':'float','datetime64[ns]':'datetime'}

# %%
do.columns = [i.replace(' ','_') for i in do.columns]

# %%
s =''
for i,j in zip(do.columns,do.dtypes.replace(r)):
    s= s+i+' '+j+', '
s=s[:-2]
s= s.replace('-','')
s
# Out:
# 'Row_ID int, Order_Priority varchar(100), Discount float, Unit_Price float, Shipping_Cost float, Customer_ID int, Customer_Name varchar(100), Ship_Mode varchar(100), Customer_Segment varchar(100), Product_Category varchar(100), Product_SubCategory varchar(100), Product_Container varchar(100), Product_Name varchar(100), Product_Base_Margin float, Region varchar(100), State_or_Province varchar(100), City varchar(100), Postal_Code int, Order_Date datetime, Ship_Date datetime, Profit float, Quantity_ordered_new int, Sales float, Order_ID int'

# %%
c.execute("Create table orders("+s+")")

# %%
for i,row in do.iterrows():
    print(tuple(row))
    c.execute("insert into orders value(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",tuple(row))
    mydb.commit()
    print("ok")
print('all inserted')
# Out:
# (18606, 'Not Specified', 0.01, 2.88, 0.5, 2, 'Janice Fletcher', 'Regular Air', 'Corporate', 'Office Supplies', 'Labels', 'Small Box', 'Avery 49', 0.36, 'Central', 'Illinois', 'Addison', 60101, Timestamp('2012-05-28 00:00:00'), Timestamp('2012-05-30 00:00:00'), 1.32, 2, 5.9, 88525)
# ok
# (20847, 'High', 0.01, 2.84, 0.93, 3, 'Bonnie Potter', 'Express Air', 'Corporate', 'Office Supplies', 'Pens & Art Supplies', 'Wrap Bag', 'SANFORD Liquid Accent™ Tank-Style Highlighters', 0.54, 'West', 'Washington', 'Anacortes', 98221, Timestamp('2010-07-07 00:00:00'), Timestamp('2010-07-08 00:00:00'), 4.56, 4, 13.01, 88522)
# ok
# (23086, 'Not Specified', 0.03, 6.68, 6.15, 3, 'Bonnie Potter', 'Express Air', 'Corporate', 'Office Supplies', 'Paper', 'Small Box', 'Xerox 1968', 0.37, 'West', 'Washington', 'Anacortes', 98221, Timestamp('2011-07-27 00:00:00'), Timestamp('2011-07-28 00:00:00'), -47.64, 7, 49.92, 88523)
# ok
# ...

# %%
p.read_sql('select * from orders',con= mydb)
# Out:
#       Row_ID Order_Priority  Discount  Unit_Price  Shipping_Cost  Customer_ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
dr.columns= [i.replace(' ','_') for i in dr.columns]

# %%
#Creating return sql
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="P05r 0t 6u4 %9jye",
                               db="task"))
dr.to_sql(con=engine, name='returns', if_exists='replace',index =False)

# %%
p.read_sql_table(table_name = 'returns',con=engine)
# Out:
#       Order_ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
du.to_sql(con=engine, name='users', if_exists='replace',index =False)

# %%
p.read_sql_table(table_name = 'users',con=engine)
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#Find out how return that we ahve recived and with a product id

# %%
p.merge(do,dr,on = 'Order_ID')[['Row_ID','Status','Product_Name']]
# Out:
#     Row_ID    Status                                       Product_Name
# 0     1359  Returned              Dixon My First Ticonderoga Pencil, #2
# 1     1950  Returned                                          Avery 493
# 2     1951  Returned                              EcoTones® Memo Sheets
# 3     5055  Returned                                          Newell 35
# 4     5573  Returned                  Staples SlimLine Pencil Sharpener
# ..     ...       ...                                                ...
# 93     986  Returned  Snap-A-Way® Black Print Carbonless Ruled Speed...
# 94     987  Returned  Recycled Steel Personal File for Standard File...
# 95    6041  Returned                                         Xerox 1980
# 96    1910  Returned                                   TDK 4.7GB DVD+RW
# 97    6625  Returned                        SAFCO Folding Chair Trolley
#
# [98 rows x 3 columns]

# %%
#try  to join order and return data both in sql and pandas

# %%
p.merge(do,dr,on = 'Order_ID',how = 'outer')
# Out:
#         Row_ID Order_Priority  Discount  Unit_Price  Shipping_Cost  \
# 0      18606.0  Not Specified      0.01        2.88           0.50
# 1      20847.0           High      0.01        2.84           0.93
# 2      23086.0  Not Specified      0.03        6.68           6.15
# 3      23087.0  Not Specified      0.01        5.68           3.60
# 4      23088.0  Not Specified      0.00      205.99           2.50
# ...        ...            ...       ...         ...            ...
# 10994      NaN            NaN       NaN         NaN            NaN
# 10995      NaN            NaN       NaN         NaN            NaN
# 10996      NaN            NaN       NaN         NaN            NaN
# 10997      NaN            NaN       NaN         NaN            NaN
# 10998      NaN            NaN       NaN         NaN            NaN
#
#        Customer_ID    Customer_Name    Ship_Mode Customer_Segment  \
# 0              2.0  Janice Fletcher  Regular Air        Corporate
# ...

# %%
sql = """select * from returns as u left join orders as o on o.Order_ID= u.Order_ID
union
select * from returns as u  right  JOIN orders as o on o.Order_ID= u.Order_ID"""
p.read_sql_query(sql,con =mydb)
# Out:
#        Order_ID    Status   Row_ID Order_Priority  Discount  Unit_Price  \
# 0        9895.0  Returned   1359.0            Low      0.05        5.85
# 1       13959.0  Returned   1951.0         Medium      0.09        4.00
# 2       13959.0  Returned   1950.0         Medium      0.01        4.91
# 3       36038.0  Returned   5055.0           High      0.02        3.28
# 4       37414.0  Returned   5257.0            Low      0.09      550.98
# ...         ...       ...      ...            ...       ...         ...
# 10994       NaN      None  20275.0       Critical      0.06       35.89
# 10995       NaN      None  20276.0       Critical      0.00        3.34
# 10996       NaN      None  24491.0  Not Specified      0.08      550.98
# 10997       NaN      None  25914.0           High      0.10      105.98
# 10998       NaN      None  24492.0  Not Specified      0.09        7.78
#
#        Shipping_Cost  Customer_ID         Customer_Name       Ship_Mode  ...  \
# ...

# %%
#Try to find out how many unique customer that we have
do['Customer_Name'].drop_duplicates()
# Out:
# 0       Janice Fletcher
# 1         Bonnie Potter
# 7        Ronnie Proctor
# 9          Dwight Hwang
# 13            Leon Gill
#              ...
# 9406      Marc McDaniel
# 9409        Marvin Reid
# 9413      Florence Gold
# 9420     Frederick Cole
# 9424      Tammy Buckley
# Name: Customer_Name, Length: 2703, dtype: object

# %%
#try to find out in how many regions we are selling a product and who is a manager for a respective region
p.merge(do,du,on = 'Region')[['Region','Manager']].drop_duplicates()
# Out:
#        Region  Manager
# 0     Central    Chris
# 2899     West  William
# 5183     East     Erin
# 7472    South      Sam

# %%
#find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
do.groupby(['Ship_Mode'])['Row_ID'].count()/do['Ship_Mode'].count()*100
# Out:
# Ship_Mode
# Delivery Truck    13.611288
# Express Air       11.744112
# Regular Air       74.644600
# Name: Row_ID, dtype: float64

# %%
do['Ship_Mode'].value_counts()/do['Ship_Mode'].count()*100
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship_Mode, dtype: float64

# %%
#Create a new coulmn and try to find our a diffrence between order date and shipment date
do['no_of_days_orderRecieved']=do['Ship_Date']-do['Order_Date']

# %%
#base on question number  find out for which order id we have shipment duration more than 10 days 
do['no_of_days_orderRecieved']=do['no_of_days_orderRecieved'].dt.days.astype(int)

# %%
do[do['no_of_days_orderRecieved']>10]['Order_ID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order_ID, dtype: int64

# %%
#Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
do[p.merge(do,du)['no_of_days_orderRecieved']>15]['Order_ID']
# Out:
# 189      2978
# 3476    22755
# 3478    27013
# 3495    87606
# 3497    87609
# 3826    90125
# 4476    13440
# 6638    89300
# 7314    87835
# 7315    87837
# 7325    39686
# 7328    90551
# 7329    90553
# 8435    89423
# 9184    87275
# 9186    86285
# 9187    86290
# 9307    90510
# Name: Order_ID, dtype: int64

# %%
#Gorup by region and find out which region is more profitable

# %%
do.groupby('Region').Profit.sum()[do.groupby('Region').Profit.sum()==max(do.groupby('Region').Profit.sum())]
# Out:
# Region
# Central    519825.567067
# Name: Profit, dtype: float64

# %%
#Try to find out overalll in which country we are giving more didscount
do.groupby('State_or_Province')['Discount'].mean()[do.groupby('State_or_Province')['Discount'].mean()==do.groupby('State_or_Province')['Discount'].mean().max()]
# Out:
# State_or_Province
# Wyoming    0.054762
# Name: Discount, dtype: float64

# %%
#Give me a list of unique postal code
do['Postal_Code'].drop_duplicates()
# Out:
# 0       60101
# 1       98221
# 7       91776
# 9       95123
# 13       2724
#         ...
# 9381     6820
# 9393    60014
# 9400    61832
# 9406    62521
# 9413    26554
# Name: Postal_Code, Length: 1697, dtype: int64

# %%
#which customer segement is more profitalble find it out

# %%
do.groupby('Customer_Segment')['Profit'].mean().sort_values(ascending=False).head(1)
# Out:
# Customer_Segment
# Small Business    171.903635
# Name: Profit, dtype: float64

# %%
#try to find out the 10th most loss making product catagory

# %%
do.groupby('Product_Name')['Profit'].mean()[do.groupby('Product_Name')['Profit'].mean()==do.groupby('Product_Name')['Profit'].mean().sort_values()[9]]
# Out:
# Product_Name
# Hewlett Packard 610 Color Digital Copier / Printer   -1255.248
# Name: Profit, dtype: float64

# %%
#Try to find out 10 top  product with highest margins

# %%
do['Product_Base_Margin']
# Out:
# 0       0.36
# 1       0.54
# 2       0.37
# 3       0.56
# 4       0.59
#         ...
# 9421    0.40
# 9422    0.54
# 9423    0.71
# 9424    0.65
# 9425    0.38
# Name: Product_Base_Margin, Length: 9426, dtype: float64

# %%
do.groupby('Product_Name')['Product_Base_Margin'].mean().sort_values(ascending = False)
# Out:
# Product_Name
# Sterling Rubber Bands by Alliance                                             1261.5
# Belkin OmniView SE Rackmount Kit                                              1261.5
# Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers    1261.5
# Accessory27                                                                   1261.5
# Accessory4                                                                    1259.0
#                                                                                ...
# Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black             5.5
# SAFCO Commercial Wire Shelving, Black                                            5.5
# SAFCO Boltless Steel Shelving                                                    5.5
# SAFCO Arco Folding Chair                                                         5.5
# SAFCO Mobile Desk Side File, Wire Frame                                          5.5
# ...

# %%
dn =p.DataFrame(do.groupby('Product_Name')['Product_Base_Margin'].mean().sort_values(ascending = False))
dn
# Out:
#                                                     Product_Base_Margin
# Product_Name
# Sterling Rubber Bands by Alliance                                  0.85
# Belkin OmniView SE Rackmount Kit                                   0.85
# Office Impressions Heavy Duty Welded Shelving &...                 0.85
# Accessory27                                                        0.85
# Accessory4                                                         0.85
# ...                                                                 ...
# Safco Value Mate Steel Bookcase, Baked Enamel F...                 0.00
# SAFCO Commercial Wire Shelving, Black                              0.00
# SAFCO Boltless Steel Shelving                                      0.00
# SAFCO Arco Folding Chair                                           0.00
# SAFCO Mobile Desk Side File, Wire Frame                            0.00
#
# [1263 rows x 1 columns]

# %%
dn["Rank_"]=dn['Product_Base_Margin'].rank(method = "dense",ascending = False)

# %%
dn[dn['Rank_']== 10]
# Out:
#                                                   Product_Base_Margin  Rank_
# Product_Name
# Eldon Base for stackable storage shelf, platinum                  0.8   10.0
